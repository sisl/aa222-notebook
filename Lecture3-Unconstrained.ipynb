# %%
using AA222
using PyPlot
# Out:
# Welcome to AA222
# Loading help data...

# %%
f(x) = x[1]^2 + 5 * x[2]^2
xdom(-5,5)
ydom(-3,3)
contour(f);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x3def590>)

# %%
x0 = [3, 1]
d = [-3, -5]
xdom(0, 0.5)
plot(alpha -> f(x0 + alpha * d));
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xa511ed0>)

# %%
xdom(-5,5)
ydom(-3,3)
contour(f);
hold("on")
quiver(x0, d)
alpha = 0.26
scatter(x0 + 0.26 * d);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xa75b510>)

# %% [markdown]
# # Steepest Descent

# %%
# This stuff is magic.
using DualNumbers
# based on https://github.com/mattjj/autodiff/blob/master/forward_mode.jl
function D(f::Function)
    function Df{T <: Real}(pt::T)
        epsilon(f(Dual(pt,1)))
    end
    function Df{T <: Real}(pt::AbstractArray{T})
        vcat([epsilon(f([Dual(x,i==j) for (j,x)=enumerate(pt)])) for i=1:length(pt)]...)
    end
end
# Out:
# D (generic function with 1 method)

# %%
f(x) = x[1]*x[2]^2
D(f)([1,2])
# Out:
# 2-element Array{Int64,1}:
#  4
#  4

# %%
# from last lecture
function bracketMinimum(f, x0 = 0, step = 1e-2, expansion = 2.0)
    x1 = x0
    f1 = f(x1)
    x2 = x1 + step
    f2 = f(x2)
    if f2 > f1
        (x1, x2) = (x2, x1)
        (f1, f2) = (f2, f1)
        step = -step;
    end
    while x1 < 1e30
        step = step * expansion
        x4 = x2 + step
        f4 = f(x4)
        if f4 > f2
            return x1 < x4 ? (x1, x4) : (x4, x1)
        end
        (x1, f1, x2, f2) = (x2, f2, x4, f4)
    end
    return x1 < x2 ? (x1, x2) : (x2, x1)
end   
function goldenSectionSearch(f, x1, x4, n)
    al = (sqrt(5) - 1) / 2
    x3 = al * x4 + (1 - al) * x1
    f3 = f(x3)
    for i = 1 : n - 1
        x2 = al * x1 + (1 - al) * x4
        f2 = f(x2)
        if f2 < f3
            x4 = x3
            x3 = x2
            f3 = f2
        else
            x1 = x4
            x4 = x2
            f4 = f2
        end
    end
    return x1 < x4 ? (x1, x4) : (x4, x1)
end
function linesearch(f)
    (lo, hi) = bracketMinimum(f)
    (lo, hi) = goldenSectionSearch(f, lo, hi, 100)
    return (lo + hi) / 2
end
# Out:
# linesearch (generic function with 1 method)

# %%
function steepestDescent(f, x0, epsG = 1e-6, epsA = 1e-6, epsR = 0.1, maxSteps = 100)
    x = x0;
    for i = 1:maxSteps
        g = D(f)(x)
        if norm(g) <= epsG
            break
        end
        d = -g / norm(g)
        f1d = alpha -> f(x + alpha * d)
        alpha = linesearch(f1d)
        x = x + alpha * d;
    end
    return x
end
# Out:
# steepestDescent (generic function with 5 methods)

# %%
f(x) = x[1]^2 + (x[2] - 2)^2
xdom(-5,5)
ydom(-5,5)
contour(f)
steepestDescent(f, [0,0])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xa73c3d0>)
# 2-element Array{Float64,1}:
#  0.0
#  2.0

# %%
function steepestDescentHistory(f, x0, epsG = 1e-6, epsA = 1e-6, epsR = 0.1, maxSteps = 100)
    x = x0;
    history = x
    for i = 1:maxSteps
        g = D(f)(x)
        if norm(g) <= epsG
            break
        end
        d = -g / norm(g)
        f1d = alpha -> f(x + alpha * d)
        alpha = linesearch(f1d)
        x = x + alpha * d;
        history = [history x]
    end
    return history
end
# Out:
# steepestDescentHistory (generic function with 5 methods)

# %%
f(x) = x[1]^2 + (x[2] - 2)^2
xdom(-5,5)
ydom(-5,5)
contour(f)
history = steepestDescentHistory(f, [0, 0])
plot(history[1,:]', history[2,:]')
show(history)
# Out:
# 2x2 Array{Float64,2}:
#  0.0  0.0
#  0.0  2.0
# Figure(PyObject <matplotlib.figure.Figure object at 0x9f39490>)

# %%
f(x) = x[1]^2 + (x[2] - 2)^2 - x[1]*x[2]
xdom(-5,5)
ydom(-5,5)
contour(f)
history = steepestDescentHistory(f, [-2,-4])
plot(history);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xf68d250>)

# %% [markdown]
# # Conjugate Gradient

# %%
A = [2 0; 0 4]
c = [-5, 5]
f(x) = (1/2) * x' * A * x + c' * x
xdom(-10, 10)
ydom(-10, 10)
contour(f)
scatter(-c' * inv(A))
-c' * inv(A)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xa756dd0>)
# 1x2 Array{Float64,2}:
#  2.5  -1.25

# %%
function conjugateGradientDescentHistory(f, x0)
    n = length(x0) # number of dimensions
    x = x0;
    history = x
    d = zeros(n)
    for i = 1:n
        g = A * x + c
        if i == 1
            beta = 0
        else
            beta = dot(g, (g - gprev)) / dot(gprev, gprev)
        end
        d = -g + beta * d
        alpha = dot(g, g) / dot(d, A * d)
        x = x + alpha * d
        history = [history x]
        gprev = g
    end
    return history
end
# Out:
# conjugateGradientDescentHistory (generic function with 1 method)

# %%
contour(f)
history = conjugateGradientDescentHistory(f, [-4,-4])
plot(history);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x9f0fb90>)

# %%
history
# Out:
# 2x3 Array{Float64,2}:
#  -4.0   0.586375   2.5
#  -4.0  -0.119221  -1.25

# %% [markdown]
# # Nonlinear Conjugate Gradient

# %% [markdown]
# This is often called the Fletcher-Reeves version of gradient descent.

# %%
function nonlinearConjugateGradientDescentHistory(f, x0, epsG = 1e-6, epsA = 1e-6, epsR = 0.1, maxSteps = 100)
    x = x0;
    history = x
    gprev = dprev = zeros(length(x0))
    for i = 1:maxSteps
        g = D(f)(x)
        if norm(g) <= epsG
            break
        end
        if i == 1
            beta = 0
        else
            beta = dot(g, g) / dot(gprev, gprev)
        end
        d = -g / norm(g) + beta * dprev
        f1d = alpha -> f(x + alpha * d)
        alpha = linesearch(f1d)
        x = x + alpha * d;
        history = [history x]
        gprev = g
        dprev = d
    end
    return history
end
# Out:
# nonlinearConjugateGradientDescentHistory (generic function with 5 methods)

# %%
A = [2 0; 0 4]
c = [-5, 5]
f(x) = (1/2) * dot(x, A * x) + dot(c, x)
xdom(-10, 10)
ydom(-10, 10)
contour(f)
history = nonlinearConjugateGradientDescentHistory(f, [-4,-4])
plot(history);
history = conjugateGradientDescentHistory(f, [-4,-4])
plot(history);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xe7251d0>)

# %%
f(x) = -sqrt(abs(x[1] * x[2])) / (1 + x[1]^2 + x[2]^2)
xdom(-5,5)
ydom(-5,5)
contour(f)
history = nonlinearConjugateGradientDescentHistory(f, [4,4])
plot(history);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x9f26f90>)
